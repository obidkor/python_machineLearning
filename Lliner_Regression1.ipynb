# %%
import tensorflow as tf

# %%
#weight bias
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf. Variable(tf.random_normal([1]), name  = 'bias')

# %%
#put data
X = tf.placeholder(tf.float32,shape=[None])
Y = tf.placeholder(tf.float32,shape=[None])

# %%
#Our hypothesis XW +b
hypothesis = X*W+b

# %%
#cost/loss fuction
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
#Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
#Launch the graph in a session
sess = tf.Session()

# %%
#Initiation global variables in the graph
sess.run(tf.global_variables_initializer())

# %%
#Fit the Line
for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost,W,b,train],
                                         feed_dict={X:[1,2,3],Y:[1,2,3]})
    if step % 20 == 0:
        print(step,cost_val,W_val,b_val)
# Out:
# 0 17.100857 [-0.49788475] [-0.4715447]
# 20 0.15824315 [0.7981313] [0.08976894]
# 40 0.0043361606 [0.9243212] [0.13688791]
# 60 0.0026744327 [0.9389901] [0.13534302]
# 80 0.0024175053 [0.9429155] [0.12944783]
# 100 0.0021955082 [0.945699] [0.12340857]
# 120 0.0019940026 [0.94826055] [0.11761305]
# 140 0.0018109772 [0.95069313] [0.11208604]
# 160 0.0016447572 [0.95301044] [0.10681839]
# 180 0.0014937975 [0.9552188] [0.10179828]
# 200 0.0013566855 [0.9573234] [0.09701412]
# 220 0.0012321705 [0.95932883] [0.09245483]
# 240 0.0011190715 [0.96124035] [0.08810983]
# 260 0.0010163599 [0.96306187] [0.083969]
# 280 0.0009230758 [0.9647978] [0.0800228]
# 300 0.00083835097 [0.9664522] [0.07626205]
# 320 0.0007614046 [0.96802884] [0.07267801]
# 340 0.0006915198 [0.9695315] [0.06926239]
# 360 0.0006280467 [0.97096336] [0.06600726]
# 380 0.0005704044 [0.97232795] [0.06290515]
# 400 0.0005180486 [0.9736284] [0.05994883]
# 420 0.0004705032 [0.97486776] [0.05713148]
# 440 0.00042731757 [0.9760489] [0.0544465]
# 460 0.000388096 [0.9771745] [0.05188771]
# 480 0.00035247215 [0.9782472] [0.04944917]
# 500 0.00032012176 [0.97926944] [0.04712525]
# 520 0.00029074188 [0.9802438] [0.04491059]
# 540 0.00026405408 [0.98117226] [0.04279993]
# 560 0.00023981808 [0.98205703] [0.04078848]
# 580 0.00021780796 [0.9829003] [0.03887157]
# 600 0.00019781699 [0.9837039] [0.03704476]
# 620 0.00017966046 [0.9844698] [0.03530382]
# 640 0.0001631714 [0.98519963] [0.03364469]
# 660 0.00014819551 [0.9858952] [0.03206351]
# 680 0.00013459248 [0.986558] [0.03055666]
# 700 0.00012224012 [0.9871897] [0.02912064]
# 720 0.00011102095 [0.98779184] [0.02775211]
# 740 0.00010082957 [0.98836553] [0.02644786]
# 760 9.1575545e-05 [0.9889122] [0.02520493]
# 780 8.317036e-05 [0.9894333] [0.02402043]
# 800 7.553775e-05 [0.9899298] [0.02289165]
# 820 6.860527e-05 [0.9904033] [0.02181585]
# 840 6.230813e-05 [0.99085426] [0.02079055]
# 860 5.6588364e-05 [0.991284] [0.01981344]
# 880 5.1394512e-05 [0.9916937] [0.01888228]
# 900 4.6677644e-05 [0.992084] [0.01799488]
# 920 4.239332e-05 [0.9924561] [0.01714919]
# 940 3.850222e-05 [0.9928106] [0.01634325]
# 960 3.4968325e-05 [0.99314845] [0.01557517]
# 980 3.175822e-05 [0.9934705] [0.0148432]
# 1000 2.8843277e-05 [0.99377733] [0.01414562]
# 1020 2.6196305e-05 [0.99406976] [0.01348082]
# 1040 2.3792172e-05 [0.99434847] [0.01284729]
# 1060 2.1608002e-05 [0.99461406] [0.01224351]
# 1080 1.9625151e-05 [0.9948672] [0.01166809]
# 1100 1.7823708e-05 [0.9951085] [0.01111972]
# 1120 1.6187481e-05 [0.99533826] [0.01059712]
# 1140 1.4701694e-05 [0.99555737] [0.01009911]
# 1160 1.3352595e-05 [0.99576616] [0.00962449]
# 1180 1.2127086e-05 [0.9959651] [0.00917218]
# 1200 1.1014246e-05 [0.9961548] [0.00874112]
# 1220 1.00034185e-05 [0.99633545] [0.00833033]
# 1240 9.0848935e-06 [0.9965077] [0.00793882]
# 1260 8.251237e-06 [0.99667186] [0.00756574]
# 1280 7.4937197e-06 [0.9968282] [0.00721015]
# 1300 6.806173e-06 [0.9969773] [0.00687131]
# 1320 6.1815044e-06 [0.99711937] [0.00654836]
# 1340 5.614149e-06 [0.9972547] [0.00624061]
# 1360 5.0987433e-06 [0.9973838] [0.00594733]
# 1380 4.630732e-06 [0.9975067] [0.00566783]
# 1400 4.205909e-06 [0.99762386] [0.00540148]
# 1420 3.8195108e-06 [0.99773556] [0.00514764]
# 1440 3.4690881e-06 [0.99784195] [0.00490572]
# 1460 3.1506697e-06 [0.9979434] [0.00467517]
# 1480 2.8615298e-06 [0.9980401] [0.00445542]
# 1500 2.5990057e-06 [0.99813217] [0.00424604]
# 1520 2.3602636e-06 [0.99821997] [0.00404649]
# 1540 2.1436983e-06 [0.99830365] [0.0038563]
# 1560 1.946956e-06 [0.9983833] [0.00367507]
# 1580 1.7683096e-06 [0.9984592] [0.00350239]
# 1600 1.6059711e-06 [0.9985317] [0.00333783]
# 1620 1.4586954e-06 [0.9986007] [0.00318096]
# 1640 1.3246569e-06 [0.9986664] [0.00303148]
# 1660 1.203127e-06 [0.9987291] [0.00288903]
# 1680 1.0928234e-06 [0.9987888] [0.00275328]
# 1700 9.925827e-07 [0.9988457] [0.00262392]
# 1720 9.013177e-07 [0.99889994] [0.00250064]
# 1740 8.1860907e-07 [0.9989516] [0.00238315]
# 1760 7.4360975e-07 [0.9990009] [0.00227118]
# 1780 6.753685e-07 [0.9990479] [0.00216445]
# 1800 6.1335186e-07 [0.9990926] [0.00206275]
# 1820 5.5714935e-07 [0.99913514] [0.00196585]
# 1840 5.059369e-07 [0.9991758] [0.00187349]
# 1860 4.5960223e-07 [0.99921453] [0.00178549]
# 1880 4.1743138e-07 [0.9992514] [0.00170159]
# 1900 3.7903388e-07 [0.9992866] [0.00162165]
# 1920 3.442788e-07 [0.99932015] [0.00154547]
# 1940 3.127227e-07 [0.99935204] [0.00147287]
# 1960 2.8403235e-07 [0.99938244] [0.00140368]
# 1980 2.579654e-07 [0.9994114] [0.00133777]
# 2000 2.343458e-07 [0.9994391] [0.00127496]

# %%
#test the model
print(sess.run(hypothesis, feed_dict={X:[5]}))
print(sess.run(hypothesis, feed_dict={X:[2.5]}))
print(sess.run(hypothesis, feed_dict={X:[1.5,3.5]}))
# Out:
# [4.998471]
# [2.499873]
# [1.5004336 3.499312 ]
